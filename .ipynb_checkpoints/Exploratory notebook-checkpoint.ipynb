# %%
import networkx as nx
import numpy as np
import pandas as pd

# %% [markdown]
# ## **Data Import**

# %%
small_dataset = pd.read_csv("../small.csv")
medium_dataset = pd.read_csv("../medium.csv")
large_dataset = pd.read_csv("../large.csv")

# %%
small_dataset.head()
# Out:
#    age  portembarked  fare  numparentschildren  passengerclass  sex  \
# 0    1             1     1                   1               1    1
# 1    2             2     1                   1               2    2
# 2    1             1     1                   1               1    2
# 3    2             1     1                   1               2    2
# 4    2             1     1                   1               1    1
#
#    numsiblings  survived
# 0            1         1
# 1            1         2
# 2            1         2
# 3            1         2
# 4            1         1

# %%
small_dataset.groupby(['age', 'portembarked']).count()
# Out:
#                   fare  numparentschildren  passengerclass  sex  numsiblings  \
# age portembarked
# 1   1              248                 248             248  248          248
#     2               57                  57              57   57           57
#     3               14                  14              14   14           14
# 2   1              363                 363             363  363          363
#     2               98                  98              98   98           98
#     3               60                  60              60   60           60
# 3   1               33                  33              33   33           33
#     2               13                  13              13   13           13
#     3                3                   3               3    3            3
#
#                   survived
# age portembarked
# 1   1                  248
#     2                   57
#     3                   14
# 2   1                  363
#     2                   98
#     3                   60
# 3   1                   33
#     2                   13
#     3                    3

# %%
medium_dataset.head()
# Out:
#    fixedacidity  volatileacidity  citricacid  residualsugar  chlorides  \
# 0             2                1           2              2          1
# 1             2                2           2              1          1
# 2             3                1           2              1          1
# 3             2                1           1              1          1
# 4             2                1           1              1          1
#
#    freesulfurdioxide  totalsulfurdioxide  density  ph  sulphates  alcohol  \
# 0                  1                   2        2   2          2        1
# 1                  1                   2        1   3          2        2
# 2                  1                   2        1   3          2        2
# 3                  1                   3        1   3          2        2
# 4                  1                   3        1   3          2        2
#
#    quality
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3

# %%
medium_dataset.groupby(['fixedacidity', 'volatileacidity']).count().values[:,0]
# Out:
# array([ 262,  181,   24,    4, 2427, 1398,  116,    9,    3,  300,  137,
#          25,    2,    3,    5,    1,    1], dtype=int64)

# %%
large_dataset.head()
# Out:
#    N1  N2  N10  N28  N13  N3  N4  N5  N8  N14 ...   N21  N39  N50  N24  N26  \
# 0   2   1    1    2    1   2   1   1   1    1 ...     2    1    1    2    1
# 1   1   1    2    1    1   1   1   2   2    1 ...     2    2    2    2    1
# 2   1   1    1    2    1   1   1   1   2    2 ...     1    2    2    2    2
# 3   1   2    2    1    1   1   2   2   2    1 ...     1    2    2    1    2
# 4   1   1    2    1    2   1   1   1   1    1 ...     1    2    1    1    1
#
#    N20  N42  N44  N32  N45
# 0    1    1    1    1    2
# 1    2    2    1    2    1
# 2    1    1    2    1    1
# 3    2    2    1    1    2
# 4    2    1    1    1    2
#
# [5 rows x 50 columns]
